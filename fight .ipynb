# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train_df=pd.read_excel('Data_Train.xlsx')
train_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
test_df=pd.read_excel('Test_set.xlsx')
test_df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
final_df=pd.merge(test_df,train_df,how="left")

# %%
final_df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info
#
#      Price
# 0      NaN
# 1      NaN
# 2      NaN
# 3  14277.0
# 4      NaN

# %%
final_df.tail()
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 2722          Air India       6/06/2019  Kolkata    Banglore  CCU → DEL → BLR
# 2723             IndiGo      27/03/2019  Kolkata    Banglore        CCU → BLR
# 2724        Jet Airways       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2725          Air India       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2726  Multiple carriers      15/06/2019    Delhi      Cochin  DEL → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 2722    20:30  20:25 07 Jun  23h 55m      1 stop         No info    NaN
# 2723    14:20         16:55   2h 35m    non-stop         No info    NaN
# 2724    21:50  04:25 07 Mar   6h 35m      1 stop         No info    NaN
# 2725    04:00         19:15  15h 15m      1 stop         No info    NaN
# 2726    04:55         19:15  14h 20m      1 stop         No info    NaN

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2727 entries, 0 to 2726
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2727 non-null   object
#  1   Date_of_Journey  2727 non-null   object
#  2   Source           2727 non-null   object
#  3   Destination      2727 non-null   object
#  4   Route            2727 non-null   object
#  5   Dep_Time         2727 non-null   object
#  6   Arrival_Time     2727 non-null   object
#  7   Duration         2727 non-null   object
#  8   Total_Stops      2727 non-null   object
#  9   Additional_Info  2727 non-null   object
#  10  Price            273 non-null    float64
# dtypes: float64(1), object(10)
# memory usage: 234.5+ KB

# %%
final_df['Date']=final_df['Date_of_Journey'].str.split('/').str[0]
final_df['Month']=final_df['Date_of_Journey'].str.split('/').str[1]
final_df['Year']=final_df['Date_of_Journey'].str.split('/').str[2]

# %%
final_df.head(2)
# Out:
#        Airline Date_of_Journey   Source Destination            Route Dep_Time  \
# 0  Jet Airways       6/06/2019    Delhi      Cochin  DEL → BOM → COK    17:30
# 1       IndiGo      12/05/2019  Kolkata    Banglore  CCU → MAA → BLR    06:20
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price Date Month  Year
# 0  04:25 07 Jun  10h 55m      1 stop         No info    NaN    6    06  2019
# 1         10:20       4h      1 stop         No info    NaN   12    05  2019

# %%
final_df['Date']=final_df['Date'].astype(int)
final_df['Month']=final_df['Month'].astype(int)
final_df['Year']=final_df['Year'].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2727 entries, 0 to 2726
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2727 non-null   object
#  1   Date_of_Journey  2727 non-null   object
#  2   Source           2727 non-null   object
#  3   Destination      2727 non-null   object
#  4   Route            2727 non-null   object
#  5   Dep_Time         2727 non-null   object
#  6   Arrival_Time     2727 non-null   object
#  7   Duration         2727 non-null   object
#  8   Total_Stops      2727 non-null   object
#  9   Additional_Info  2727 non-null   object
#  10  Price            273 non-null    float64
#  11  Date             2727 non-null   int64
#  12  Month            2727 non-null   int64
#  13  Year             2727 non-null   int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 298.4+ KB

# %%
final_df.drop('Date_of_Journey',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#              Airline    Source Destination            Route Dep_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55
#
#    Arrival_Time Duration Total_Stops              Additional_Info    Price  \
# 0  04:25 07 Jun  10h 55m      1 stop                      No info      NaN
# 1         10:20       4h      1 stop                      No info      NaN
# 2  19:00 22 May  23h 45m      1 stop  In-flight meal not included      NaN
# 3         21:00      13h      1 stop                      No info  14277.0
# 4  02:45 25 Jun   2h 50m    non-stop                      No info      NaN
#
#    Date  Month  Year
# 0     6      6  2019
# 1    12      5  2019
# 2    21      5  2019
# 3    21      5  2019
# 4    24      6  2019

# %%
final_df['Arrival_Time'].str.split("  ").str[0]
# Out:
# 0       04:25 07 Jun
# 1              10:20
# 2       19:00 22 May
# 3              21:00
# 4       02:45 25 Jun
#             ...
# 2722    20:25 07 Jun
# 2723           16:55
# 2724    04:25 07 Mar
# 2725           19:15
# 2726           19:15
# Name: Arrival_Time, Length: 2727, dtype: object

# %%
final_df.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 0
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           0
# Additional_Info       0
# Price              2454
# Date                  0
# Month                 0
# Year                  0
# dtype: int64

# %%
final_df[['Arrival_hour', 'Arrival_min']] = final_df['Arrival_Time'].str.extract(r'(\d{2}):(\d{2})')

# %%
final_df.head(1)
# Out:
#        Airline Source Destination            Route Dep_Time  Arrival_Time  \
# 0  Jet Airways  Delhi      Cochin  DEL → BOM → COK    17:30  04:25 07 Jun
#
#   Duration Total_Stops Additional_Info  Price  Date  Month  Year Arrival_hour  \
# 0  10h 55m      1 stop         No info    NaN     6      6  2019           04
#
#   Arrival_min
# 0          25

# %%
final_df['Arrival_hour']=final_df['Arrival_hour'].astype(int)
final_df['Arrival_min']=final_df['Arrival_min'].astype(int)

# %%
final_df.drop('Arrival_Time',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#              Airline    Source Destination            Route Dep_Time Duration  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30  10h 55m
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20       4h
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15  23h 45m
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00      13h
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55   2h 50m
#
#   Total_Stops              Additional_Info    Price  Date  Month  Year  \
# 0      1 stop                      No info      NaN     6      6  2019
# 1      1 stop                      No info      NaN    12      5  2019
# 2      1 stop  In-flight meal not included      NaN    21      5  2019
# 3      1 stop                      No info  14277.0    21      5  2019
# 4    non-stop                      No info      NaN    24      6  2019
#
#    Arrival_hour  Arrival_min
# 0             4           25
# 1            10           20
# 2            19            0
# 3            21            0
# 4             2           45

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2727 entries, 0 to 2726
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2727 non-null   object
#  1   Source           2727 non-null   object
#  2   Destination      2727 non-null   object
#  3   Route            2727 non-null   object
#  4   Dep_Time         2727 non-null   object
#  5   Arrival_Time     2727 non-null   object
#  6   Duration         2727 non-null   object
#  7   Total_Stops      2727 non-null   object
#  8   Additional_Info  2727 non-null   object
#  9   Price            273 non-null    float64
#  10  Date             2727 non-null   int64
#  11  Month            2727 non-null   int64
#  12  Year             2727 non-null   int64
#  13  Arrival_hour     2727 non-null   int64
#  14  Arrival_min      2727 non-null   int64
# dtypes: float64(1), int64(5), object(9)
# memory usage: 319.7+ KB

# %%
final_df['Dept_hour']=final_df['Dep_Time'].str.split(':').str[0]
final_df['Dept_min']=final_df['Dep_Time'].str.split(':').str[1]
final_df['Dept_hour']=final_df['Dept_hour'].astype(int)
final_df['Dept_min']=final_df['Dept_min'].astype(int)
final_df.drop('Dep_Time',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#              Airline    Source Destination            Route Duration  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK  10h 55m
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR       4h
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK  23h 45m
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK      13h
# 4           Air Asia  Banglore       Delhi        BLR → DEL   2h 50m
#
#   Total_Stops              Additional_Info    Price  Date  Month  Year  \
# 0      1 stop                      No info      NaN     6      6  2019
# 1      1 stop                      No info      NaN    12      5  2019
# 2      1 stop  In-flight meal not included      NaN    21      5  2019
# 3      1 stop                      No info  14277.0    21      5  2019
# 4    non-stop                      No info      NaN    24      6  2019
#
#    Arrival_hour  Arrival_min  Dept_hour  Dept_min
# 0             4           25         17        30
# 1            10           20          6        20
# 2            19            0         19        15
# 3            21            0          8         0
# 4             2           45         23        55

# %%
final_df['Total_Stops'].unique()
# Out:
# array(['1 stop', 'non-stop', '2 stops', '3 stops', '4 stops'],
#       dtype=object)

# %%
final_df['Total_Stops']=final_df['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,'nan':1})

# %%
final_df.head()
# Out:
#              Airline    Source Destination            Route Duration  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK  10h 55m
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR       4h
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK  23h 45m
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK      13h
# 4           Air Asia  Banglore       Delhi        BLR → DEL   2h 50m
#
#    Total_Stops              Additional_Info    Price  Date  Month  Year  \
# 0            1                      No info      NaN     6      6  2019
# 1            1                      No info      NaN    12      5  2019
# 2            1  In-flight meal not included      NaN    21      5  2019
# 3            1                      No info  14277.0    21      5  2019
# 4            0                      No info      NaN    24      6  2019
#
#    Arrival_hour  Arrival_min  Dept_hour  Dept_min
# 0             4           25         17        30
# 1            10           20          6        20
# 2            19            0         19        15
# 3            21            0          8         0
# 4             2           45         23        55

# %%
final_df.drop('Route',axis=1,inplace=True)

# %%
final_df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Long layover', 'Business class',
#        'Change airports'], dtype=object)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2727 entries, 0 to 2726
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2727 non-null   object
#  1   Source           2727 non-null   object
#  2   Destination      2727 non-null   object
#  3   Duration         2727 non-null   object
#  4   Total_Stops      2727 non-null   int64
#  5   Additional_Info  2727 non-null   object
#  6   Price            273 non-null    float64
#  7   Date             2727 non-null   int64
#  8   Month            2727 non-null   int64
#  9   Year             2727 non-null   int64
#  10  Arrival_hour     2727 non-null   int64
#  11  Arrival_min      2727 non-null   int64
#  12  Dept_hour        2727 non-null   int64
#  13  Dept_min         2727 non-null   int64
# dtypes: float64(1), int64(8), object(5)
# memory usage: 298.4+ KB

# %%
final_df['duration_hour']=final_df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
 final_df[final_df['duration_hour']=='5m']
# Out:
#         Airline  Source Destination Duration  Total_Stops Additional_Info  \
# 2716  Air India  Mumbai   Hyderabad       5m            2         No info
#
#       Price  Date  Month  Year  Arrival_hour  Arrival_min  Dept_hour  \
# 2716    NaN    12      3  2019            16           55         16
#
#       Dept_min duration_hour
# 2716        50            5m

# %%
final_df.drop(2716,axis=0,inplace=True)

# %%
final_df['duration_hour']=final_df['duration_hour'].astype('int')

# %%
final_df.drop('Duration',axis=1,inplace=True)

# %%
final_df.head(1)
# Out:
#        Airline Source Destination  Total_Stops Additional_Info  Price  Date  \
# 0  Jet Airways  Delhi      Cochin            1         No info    NaN     6
#
#    Month  Year  Arrival_hour  Arrival_min  Dept_hour  Dept_min  duration_hour
# 0      6  2019             4           25         17        30             10

# %%
final_df['Airline'].unique()
# Out:
# array(['Jet Airways', 'IndiGo', 'Multiple carriers', 'Air Asia',
#        'Air India', 'Vistara', 'SpiceJet', 'Vistara Premium economy',
#        'GoAir', 'Multiple carriers Premium economy',
#        'Jet Airways Business'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()

# %%
final_df['Airline']=labelencoder.fit_transform(final_df['Airline'])
final_df['Source']=labelencoder.fit_transform(final_df['Source'])
final_df['Destination']=labelencoder.fit_transform(final_df['Destination'])
final_df['Additional_Info']=labelencoder.fit_transform(final_df['Additional_Info'])

# %%
pd.get_dummies(final_df,columns=["Airline", "Source", "Destination"] ,drop_first = True)
# Out:
#       Total_Stops  Additional_Info    Price  Date  Month  Year  Arrival_hour  \
# 0               1                5      NaN     6      6  2019             4
# 1               1                5      NaN    12      5  2019            10
# 2               1                3      NaN    21      5  2019            19
# 3               1                5  14277.0    21      5  2019            21
# 4               0                5      NaN    24      6  2019             2
# ...           ...              ...      ...   ...    ...   ...           ...
# 2722            1                5      NaN     6      6  2019            20
# 2723            0                5      NaN    27      3  2019            16
# 2724            1                5      NaN     6      3  2019             4
# 2725            1                5      NaN     6      3  2019            19
# 2726            1                5      NaN    15      6  2019            19
#
#       Arrival_min  Dept_hour  Dept_min  ...  Airline_10  Source_1  Source_2  \
# 0              25         17        30  ...       False     False      True
# 1              20          6        20  ...       False     False     False
# 2               0         19        15  ...       False     False      True
# 3               0          8         0  ...       False     False      True
# 4              45         23        55  ...       False     False     False
# ...           ...        ...       ...  ...         ...       ...       ...
# 2722           25         20        30  ...       False     False     False
# 2723           55         14        20  ...       False     False     False
# 2724           25         21        50  ...       False     False      True
# 2725           15          4         0  ...       False     False      True
# 2726           15          4        55  ...       False     False      True
#
#       Source_3  Source_4  Destination_1  Destination_2  Destination_3  \
# 0        False     False           True          False          False
# 1         True     False          False          False          False
# 2        False     False           True          False          False
# 3        False     False           True          False          False
# 4        False     False          False           True          False
# ...        ...       ...            ...            ...            ...
# 2722      True     False          False          False          False
# 2723      True     False          False          False          False
# 2724     False     False           True          False          False
# 2725     False     False           True          False          False
# 2726     False     False           True          False          False
#
#       Destination_4  Destination_5
# 0             False          False
# 1             False          False
# 2             False          False
# 3             False          False
# 4             False          False
# ...             ...            ...
# 2722          False          False
# 2723          False          False
# 2724          False          False
# 2725          False          False
# 2726          False          False
#
# [2726 rows x 30 columns]
